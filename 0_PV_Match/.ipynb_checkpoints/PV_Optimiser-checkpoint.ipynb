# %%
# PV Optimization Notebook
# ========================
# Uses simulate_pv() from scripts/PV_Calculation.py to find optimal system losses.

import os, sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Setup paths & import
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
scripts_dir  = os.path.join(project_root, 'scripts')
sys.path.insert(0, scripts_dir)

from PV_Calculation import simulate_pv

data_dir     = os.path.join(project_root, 'data')
weather_file = os.path.join(data_dir, 'Bonfire_2025.epw')
measured_csv = os.path.join(data_dir, 'PV_Generation_excel.csv')
output_pref  = os.path.join(project_root, 'pv_optimized_losses')

# 2️⃣ Load measured half-hourly data (exclude missing period)
def load_measured(path: str) -> pd.Series:
    df = pd.read_csv(
        path,
        usecols=[0, 1],
        names=['datetime', 'measured_kwh'],
        header=0,
        parse_dates=['datetime']
    )
    df.set_index('datetime', inplace=True)
    # drop missing interval
    start_missing = pd.Timestamp('2024-03-03 18:00')
    end_missing   = pd.Timestamp('2024-08-27 17:00')
    return df[(df.index < start_missing) | (df.index > end_missing)]['measured_kwh']

measured = load_measured(measured_csv)
print("Measured data from", measured.index.min(), "to", measured.index.max())

# 3️⃣ Simulate & upsample
def simulate_hourly_pv(loss_pct: float) -> pd.Series:
    df_hourly = simulate_pv(
        weather_file=weather_file,
        system_capacity_kw=10.0,
        losses_pct=loss_pct,
        start_year=2024
    )
    return df_hourly['simulated_kwh']

def to_halfhourly(hourly: pd.Series) -> pd.Series:
    return hourly.resample('30min').interpolate('linear')

# 4️⃣ Daily % difference
def daily_pct_diff(sim: pd.Series, meas: pd.Series) -> pd.DataFrame:
    sim_d  = sim.resample('D').sum()
    meas_d = meas.resample('D').sum()
    df     = pd.concat([sim_d, meas_d], axis=1, join='inner')
    df.columns = ['sim','meas']
    df = df[df['meas'] > 0]
    df['pct_diff'] = ((df['sim'] - df['meas']).abs() / df['meas']) * 100
    return df[['pct_diff']]

# 5️⃣ Grid search: 10% → 50% in 0.5% steps
loss_range = np.arange(10.0, 50.1, 0.5)
threshold  = 10.0
best = {'loss':None, 'avg_diff':np.inf}

for loss in loss_range:
    sim_hh   = to_halfhourly(simulate_hourly_pv(loss))
    daily_df = daily_pct_diff(sim_hh, measured)
    avg_pct  = daily_df['pct_diff'].mean()
    if avg_pct < best['avg_diff']:
        best.update({
            'loss': loss,
            'avg_diff': avg_pct,
            'daily_df': daily_df,
            'sim_hh': sim_hh
        })

# 6️⃣ Report & export
print(f"Optimal losses: {best['loss']}% → Avg daily diff = {best['avg_diff']:.2f}%")
print("✅ Within threshold" if best['avg_diff'] <= threshold else "⚠️ Above threshold")

# write out CSVs
daily_csv    = f"{output_pref}_{best['loss']}pct_daily_diff.csv"
half_csv     = f"{output_pref}_{best['loss']}pct_halfhourly.csv"
best['daily_df'].to_csv(daily_csv, index_label='date')
pd.concat([measured, best['sim_hh']], axis=1).to_csv(half_csv, index_label='datetime')

print("Saved daily diff CSV:", daily_csv)
print("Saved half-hourly CSV:", half_csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 scripts_dir  = os.path.join(project_root, 'scripts')
#      13 sys.path.insert(0, scripts_dir)
# ---> 15 from PV_Calculation import simulate_pv
#      17 data_dir     = os.path.join(project_root, 'data')
#      18 weather_file = os.path.join(data_dir, 'Bonfire_2025.epw')
#
# File ~/Documents/GitHub/Battery_Optimisation/scripts/PV_Calculation.py:5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "d15f44fc-5aa3-4953-9a20-d9f000714af1",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "I am getting crazy results. So, this is my PV_Calculation code. however if I run it, I get this error.\n",
#      11     "\n",
#      12     "# pv_calculation.py\n",
#      13     "\n",
#      14     "import PySAM.Pvwattsv8 as pv\n",
#      15     "import pandas as pd\n",
#      16     "import numpy as np\n",
#      17     "from datetime import datetime, timedelta\n",
#      18     "\n",
#      19     "def load_data(csv_path: str) -> pd.DataFrame:\n",
#      20     "    \"\"\"\n",
#      21     "    Load measured generation from a CSV with:\n",
#      22     "      • Column A: datetime strings in 'YYYY-MM-DD HH:MM'\n",
#      23     "      • Column B: measured generation (kWh or W, adjust if needed)\n",
#      24     "    \"\"\"\n",
#      25     "    df = pd.read_csv(\n",
#      26     "        csv_path,\n",
#      27     "        usecols=[0, 1],\n",
#      28     "        names=['datetime', 'measured_kwh'],\n",
#      29     "        header=0,\n",
#      30     "        parse_dates=['datetime']\n",
#      31     "    )\n",
#      32     "    df.set_index('datetime', inplace=True)\n",
#      33     "    return df\n",
#      34     "\n",
#      35     "def simulate_pv(\n",
#      36     "    weather_file: str,\n",
#      37     "    system_capacity_kw: float = 10.0,\n",
#      38     "    losses_pct: float = 20.28,\n",
#      39     "    start_year: int = 2024\n",
#      40     ") -> pd.DataFrame:\n",
#      41     "    \"\"\"\n",
#      42     "    Run a PVWatts simulation with only an overall loss factor.\n",
#      43     "    Returns an hourly DataFrame indexed by Timestamp with column 'simulated_kwh'.\n",
#      44     "    \"\"\"\n",
#      45     "    # build your PV model\n",
#      46     "    pv_system = pv.default('PVWattsNone')\n",
#      47     "    pv_system.SolarResource.solar_resource_file = weather_file\n",
#      48     "\n",
#      49     "    # basic system design\n",
#      50     "    pv_system.SystemDesign.system_capacity = system_capacity_kw\n",
#      51     "    pv_system.SystemDesign.dc_ac_ratio    = 1.15\n",
#      52     "    pv_system.SystemDesign.inv_eff        = 96\n",
#      53     "    pv_system.SystemDesign.tilt           = 10\n",
#      54     "    pv_system.SystemDesign.azimuth        = 18\n",
#      55     "    pv_system.SystemDesign.array_type     = 1      # roof‐mount\n",
#      56     "    pv_system.SystemDesign.module_type    = 0      # standard module\n",
#      57     "    pv_system.SystemDesign.gcr            = 0.3    # ground coverage ratio\n",
#      58     "    pv_system.SystemDesign.losses         = losses_pct\n",
#      59     "\n",
#      60     "    # run it\n",
#      61     "    pv_system.execute()\n",
#      62     "\n",
#      63     "    # pull out AC output (Watts→kWh)\n",
#      64     "    ac_watts = np.array(pv_system.Outputs.ac)\n",
#      65     "    ac_kwh   = ac_watts / 1000.0\n",
#      66     "\n",
#      67     "    # build a DatetimeIndex for the full year\n",
#      68     "    start = datetime(start_year, 1, 1, 0, 0)\n",
#      69     "    times = pd.date_range(start, periods=len(ac_kwh), freq='H')\n",
#      70     "\n",
#      71     "    return pd.DataFrame({'simulated_kwh': ac_kwh}, index=times)\n",
#      72     "\n",
#      73     "def main():\n",
#      74     "    project_dir      = os.path.abspath(os.getcwd())  # adjust as needed\n",
#      75     "    weather_file     = os.path.join(project_dir, 'data', 'Bonfire_2025.epw')\n",
#      76     "    measured_csv     = os.path.join(project_dir, 'data', 'PV_Generation_excel.csv')\n",
#      77     "\n",
#      78     "    # 1) load measured data\n",
#      79     "    measured = load_data(measured_csv)\n",
#      80     "\n",
#      81     "    # 2) run simulation\n",
#      82     "    simulated = simulate_pv(\n",
#      83     "        weather_file=weather_file,\n",
#      84     "        system_capacity_kw=10.0,\n",
#      85     "        losses_pct=20.28,\n",
#      86     "        start_year=2024\n",
#      87     "    )\n",
#      88     "\n",
#      89     "    # 3) simple sanity‐check printouts\n",
#      90     "    print(\"Measured head:\\n\",   measured.head(), \"\\n\")\n",
#      91     "    print(\"Simulated head:\\n\", simulated.head(), \"\\n\")\n",
#      92     "    \n",
#      93     "    # if you want to compare month‐by‐month in‐memory:\n",
#      94     "    meas_m = measured.resample('ME').sum()\n",
#      95     "    sim_m  = simulated.resample('ME').sum()\n",
#      96     "    diff   = (sim_m - meas_m) / meas_m * 100\n",
#      97     "    print(\"Monthly diff %:\\n\", diff)\n",
#      98     "\n",
#      99     "if __name__ == '__main__':\n",
#     100     "    import os\n",
#     101     "    main()\n",
#     102     "\n",
#     103     "---------------------------------------------------------------------------\n",
#     104     "FileNotFoundError                         Traceback (most recent call last)\n",
#     105     "Cell In[2], line 90\n",
#     106     "     88 if __name__ == '__main__':\n",
#     107     "     89     import os\n",
#     108     "---> 90     main()\n",
#     109     "\n",
#     110     "Cell In[2], line 68, in main()\n",
#     111     "     65 measured_csv     = os.path.join(project_dir, 'data', 'PV_Generation_excel.csv')\n",
#     112     "     67 # 1) load measured data\n",
#     113     "---> 68 measured = load_data(measured_csv)\n",
#     114     "     70 # 2) run simulation\n",
#     115     "     71 simulated = simulate_pv(\n",
#     116     "     72     weather_file=weather_file,\n",
#     117     "     73     system_capacity_kw=10.0,\n",
#     118     "     74     losses_pct=20.28,\n",
#     119     "     75     start_year=2024\n",
#     120     "     76 )\n",
#     121     "\n",
#     122     "Cell In[2], line 14, in load_data(csv_path)\n",
#     123     "      8 def load_data(csv_path: str) -> pd.DataFrame:\n",
#     124     "      9     \"\"\"\n",
#     125     "     10     Load measured generation from a CSV with:\n",
#     126     "     11       • Column A: datetime strings in 'YYYY-MM-DD HH:MM'\n",
#     127     "     12       • Column B: measured generation (kWh or W, adjust if needed)\n",
#     128     "     13     \"\"\"\n",
#     129     "---> 14     df = pd.read_csv(\n",
#     130     "     15         csv_path,\n",
#     131     "     16         usecols=[0, 1],\n",
#     132     "     17         names=['datetime', 'measured_kwh'],\n",
#     133     "     18         header=0,\n",
#     134     "     19         parse_dates=['datetime']\n",
#     135     "     20     )\n",
#     136     "     21     df.set_index('datetime', inplace=True)\n",
#     137     "     22     return df\n",
#     138     "\n",
#     139     "File /opt/anaconda3/envs/pysam_project/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)\n",
#     140     "   1013 kwds_defaults = _refine_defaults_read(\n",
#     141     "   1014     dialect,\n",
#     142     "   1015     delimiter,\n",
#     143     "   (...)   1022     dtype_backend=dtype_backend,\n",
#     144     "   1023 )\n",
#     145     "   1024 kwds.update(kwds_defaults)\n",
#     146     "-> 1026 return _read(filepath_or_buffer, kwds)\n",
#     147     "\n",
#     148     "File /opt/anaconda3/envs/pysam_project/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)\n",
#     149     "    617 _validate_names(kwds.get(\"names\", None))\n",
#     150     "    619 # Create the parser.\n",
#     151     "--> 620 parser = TextFileReader(filepath_or_buffer, **kwds)\n",
#     152     "    622 if chunksize or iterator:\n",
#     153     "    623     return parser\n",
#     154     "\n",
#     155     "File /opt/anaconda3/envs/pysam_project/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)\n",
#     156     "   1617     self.options[\"has_index_names\"] = kwds[\"has_index_names\"]\n",
#     157     "   1619 self.handles: IOHandles | None = None\n",
#     158     "-> 1620 self._engine = self._make_engine(f, self.engine)\n",
#     159     "\n",
#     160     "File /opt/anaconda3/envs/pysam_project/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)\n",
#     161     "   1878     if \"b\" not in mode:\n",
#     162     "   1879         mode += \"b\"\n",
#     163     "-> 1880 self.handles = get_handle(\n",
#     164     "   1881     f,\n",
#     165     "   1882     mode,\n",
#     166     "   1883     encoding=self.options.get(\"encoding\", None),\n",
#     167     "   1884     compression=self.options.get(\"compression\", None),\n",
#     168     "   1885     memory_map=self.options.get(\"memory_map\", False),\n",
#     169     "   1886     is_text=is_text,\n",
#     170     "   1887     errors=self.options.get(\"encoding_errors\", \"strict\"),\n",
#     171     "   1888     storage_options=self.options.get(\"storage_options\", None),\n",
#     172     "   1889 )\n",
#     173     "   1890 assert self.handles is not None\n",
#     174     "   1891 f = self.handles.handle\n",
#     175     "\n",
#     176     "File /opt/anaconda3/envs/pysam_project/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)\n",
#     177     "    868 elif isinstance(handle, str):\n",
#     178     "    869     # Check whether the filename is to be opened in binary mode.\n",
#     179     "    870     # Binary mode does not support 'encoding' and 'newline'.\n",
#     180     "    871     if ioargs.encoding and \"b\" not in ioargs.mode:\n",
#     181     "    872         # Encoding\n",
#     182     "--> 873         handle = open(\n",
#     183     "    874             handle,\n",
#     184     "    875             ioargs.mode,\n",
#     185     "    876             encoding=ioargs.encoding,\n",
#     186     "    877             errors=errors,\n",
#     187     "    878             newline=\"\",\n",
#     188     "    879         )\n",
#     189     "    880     else:\n",
#     190     "    881         # Binary mode\n",
#     191     "    882         handle = open(handle, ioargs.mode)\n",
#     192     "\n",
#     193     "FileNotFoundError: [Errno 2] No such file or directory: '/Users/petertunali/Documents/GitHub/Battery_Optimisation/notebooks/data/PV_Generation_excel.csv'\n",
#     194     "\n",
#     195     "Click to add a cell."
#     196    ]
#     197   }
#     198  ],
#     199  "metadata": {
#     200   "kernelspec": {
#     201    "display_name": "Python 3 (ipykernel)",
#     202    "language": "python",
#     203    "name": "python3"
#     204   },
#     205   "language_info": {
#     206    "codemirror_mode": {
#     207     "name": "ipython",
#     208     "version": 3
#     209    },
#     210    "file_extension": ".py",
#     211    "mimetype": "text/x-python",
#     212    "name": "python",
#     213    "nbconvert_exporter": "python",
#     214    "pygments_lexer": "ipython3",
#     215    "version": "3.12.9"
#     216   }
#     217  },
#     218  "nbformat": 4,
#     219  "nbformat_minor": 5
#     220 }
#
# NameError: name 'null' is not defined
